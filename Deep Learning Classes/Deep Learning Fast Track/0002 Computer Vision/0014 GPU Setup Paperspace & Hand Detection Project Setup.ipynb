# %% [markdown]
# ## Lamdalabs blog for Choosing a gpu for Deep Learning
# https://lambdalabs.com/blog/choosing-a-gpu-for-deep-learning/

# %% [markdown]
# ## Ques : Why nvidia gpu's for deep Learning ? Why not AMD ?
# ### The Specific tensor Processing unit is developed by CUDA
# ### AMD didn't developed Specific Tensor processing unit till now
# ### So most of the People use nvidia for Deep Learning

# %% [markdown]
# ## CUDA Enabled Products and GPU's by nvidia
# https://developer.nvidia.com/cuda-gpus#compute
#
# https://developer.nvidia.com/cuda-gpus

# %% [markdown]
# ### NVIDIA CUDA Cores around 2000 is a Descent GPU
# ### NVIDIA CUDA Cores above 3000 is a Good GPU
# ### NVIDIA CUDA Cores above 4000 is a Best GPU

# %% [markdown]
# ## Ques : How  to Choose nvidia GPU's ?

# %% [markdown]
# ## 1. NVIDIA CUDA cores
# ### GEFORCE RTX 2060
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# ## 2. Memory Size :
# ### Memory Size matters more than the CUDA cores
# ![3.PNG](attachment:3.PNG)
#
#
# ### Eg : NVIDIA RTX 2060 has 6 GB GDDR6 Video RAM with CUDA cores : 1920
# ### Eg : Other GPU has 4 GB GDDR6 with CUDA cores : 3000
#
# ## Which one to Coose ?
# ### Choose the one with more Memory Size and V RAM
# ### When Memory Size and V RAM is Much Higher ( 6GB or 8GB ), at that point of time  Number CUDA cores doesn't come into picture

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# ### Till now 2080 Ti is the Best GPU available in the Laptop Till now

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %% [markdown]
# ![7.PNG](attachment:7.PNG)

# %% [markdown]
# ## Why paperspace ??
# ### Paperspace is one of the cheapest option available compared to Microsoft Azure , GCP , AWS

# %% [markdown]
# ### When you login for the first time in Paperspace  you can see gradient and CORE
# ![8.PNG](attachment:8.PNG)

# %% [markdown]
# ### gradients are like jupyter notebooks (free gpu's but limited)
# ### But there is no Runtime disconnectivity  like in Google colab

# %% [markdown]
# ![10.PNG](attachment:10.PNG)

# %% [markdown]
# ![9.PNG](attachment:9.PNG)

# %% [markdown]
# ## CORE : If we need to get Complete access to Virtual Machine VM then Choose CORE

# %% [markdown]
# ### Click on CORE
# ### Create Machine
# ### Choose Region as Amsterdam
# ![11.PNG](attachment:11.PNG)

# %% [markdown]
# ### Choose OS : Ubuntu 18.04 ML in a Box
# ### Because in Ubuntu 18.04 ML in a Box , all the necessary nvidia drivers are pre installed , some libraries are pre installed
# ### we don't have to install . Just Launch and start working
# ![12.PNG](attachment:12.PNG)

# %% [markdown]
# ![13.PNG](attachment:13.PNG)

# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %% [markdown]
# ![15.PNG](attachment:15.PNG)

# %% [markdown]
# ![16.PNG](attachment:16.PNG)
